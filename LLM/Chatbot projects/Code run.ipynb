# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Gooogle Colab projects/NLP/Chatbot projects/
# Out:
# /content/drive/MyDrive/Gooogle Colab projects/NLP/Chatbot projects

# %%
import sys
import os

# Add the project root folder to sys.path so Python can find your modules
project_root = "/content/drive/MyDrive/Gooogle Colab projects/NLP/Chatbot projects"
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 318.0/363.4 MB 100.4 MB/s eta 0:00:01
# ERROR: Operation cancelled by user

# %%
pip install rouge_score

# %%
## Run model directly
# !python main.py --config configs/default.yaml --mode train
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# DEBUG - Config keys: dict_keys(['model', 'tokenizer', 'training', 'data', 'generation'])
# DEBUG - Training config: {'epochs': 10, 'batch_size': 32, 'learning_rate': 0.0005, 'save_path': 'models/dialoGPT_small', 'loss_type': 'cross_entropy'}
# DEBUG - Type of training config: <class 'dict'>
# DEBUG - Training config keys: dict_keys(['epochs', 'batch_size', 'learning_rate', 'save_path', 'loss_type'])
# DEBUG - batch_size: 32
# DEBUG - learning_rate: 0.0005
# DEBUG - type(batch_size): <class 'int'>
# DEBUG - type(learning_rate): <class 'float'>
# data_loader.py loaded successfully
# Training process started
# Tokenizer initialized
# Using processed data path: /content/drive/MyDrive/Gooogle Colab projects/NLP/Chatbot projects/data/processed.txt
# ...
